# %%
# !git clone --recursive https://github.com/matejgrcic/DenseFlow.git
# !pip install wget
# %cd DenseFlow
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# Cloning into 'DenseFlow'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 277 (delta 50), reused 260 (delta 44), pack-reused 0
# Receiving objects: 100% (277/277), 1.16 MiB | 23.85 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=524266ebfd6be39a2bbe441aeb18fd64f62cb1e22ff1297a1a9c12560ec0de8b
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...
# /content/DenseFlow
# ...
#      |████████████████████████████████| 147 kB 10.0 MB/s
# ...
#      |████████████████████████████████| 178 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.8 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 166 kB 66.8 MB/s
# ...

# %%
# !python /content/DenseFlow/denseflow/data/datasets/image/imagenet32.py

# %%
# %cd /content/DenseFlow
# Out:
# /content/DenseFlow

# %%
mkdir -p ./data/imagenet32/{raw,processed}

# %%
cp ./make_imagenet_data.py ./data/imagenet32/processed/

# %%
cd /content/DenseFlow/data/imagenet32/raw
# Out:
# /content/DenseFlow/data/imagenet32/raw

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !wget https://image-net.org/data/downsample/Imagenet32_train.zip
# !wget https://image-net.org/data/downsample/Imagenet32_val.zip
# Out:
# --2021-11-04 12:12:03--  https://image-net.org/data/downsample/Imagenet32_train.zip
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3590350354 (3.3G) [application/zip]
# Saving to: ‘Imagenet32_train.zip’
#
# Imagenet32_train.zi 100%[===================>]   3.34G  16.2MB/s    in 3m 4s
#
# 2021-11-04 12:15:08 (18.6 MB/s) - ‘Imagenet32_train.zip’ saved [3590350354/3590350354]
#
# --2021-11-04 12:15:08--  https://image-net.org/data/downsample/Imagenet32_val.zip
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140074979 (134M) [application/zip]
# Saving to: ‘Imagenet32_val.zip’
#
# Imagenet32_val.zip  100%[===================>] 133.58M  25.0MB/s    in 5.9s
#
# ...

# %%
# !unzip Imagenet32_train.zip
# !unzip Imagenet32_val.zip
# Out:
# Archive:  Imagenet32_train.zip
#   inflating: train_data_batch_1
#   inflating: train_data_batch_2
#   inflating: train_data_batch_3
#   inflating: train_data_batch_4
#   inflating: train_data_batch_5
#   inflating: train_data_batch_6
#   inflating: train_data_batch_7
#   inflating: train_data_batch_8
#   inflating: train_data_batch_9
#   inflating: train_data_batch_10
# Archive:  Imagenet32_val.zip
#   inflating: val_data

# %%
# %cd ../processed
# Out:
# /content/DenseFlow/data/imagenet32/processed

# %%
mkdir -p ./{train_32x32,valid_32x32}

# %%
# !python make_imagenet_data.py --img_size 32
# Out:
# > Processed 1281167 training images!
# > Processed 50000 validation images!

# %%
# %cd /content/DenseFlow
# Out:
# /content/DenseFlow

# %%
mkdir -p ./data/imagenet64/{raw,processed}

# %%
cp ./make_imagenet_data.py ./data/imagenet64/processed/

# %%
# %cd ./data/imagenet64/raw
# Out:
# /content/DenseFlow/data/imagenet64/raw

# %%
# !wget https://image-net.org/data/downsample/Imagenet64_train_part1.zip
# !wget https://image-net.org/data/downsample/Imagenet64_train_part2.zip
# !wget https://image-net.org/data/downsample/Imagenet64_val.zip
# Out:
# --2021-11-03 23:08:57--  https://image-net.org/data/downsample/Imagenet64_train_part1.zip
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6837429926 (6.4G) [application/zip]
# Saving to: ‘Imagenet64_train_part1.zip’
#
# Imagenet64_train_pa 100%[===================>]   6.37G  13.9MB/s    in 8m 26s
#
# 2021-11-03 23:17:23 (12.9 MB/s) - ‘Imagenet64_train_part1.zip’ saved [6837429926/6837429926]
#
# --2021-11-03 23:17:23--  https://image-net.org/data/downsample/Imagenet64_train_part2.zip
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6834457024 (6.4G) [application/zip]
# Saving to: ‘Imagenet64_train_part2.zip’
#
# Imagenet64_train_pa 100%[===================>]   6.36G  14.6MB/s    in 9m 49s
#
# ...

# %%
# !unzip Imagenet64_train_part1.zip
# !unzip Imagenet64_train_part2.zip
# !unzip Imagenet64_val.zip
# Out:
# Archive:  Imagenet64_train_part1.zip
#   inflating: train_data_batch_1
#   inflating: train_data_batch_2
#   inflating: train_data_batch_3
#   inflating: train_data_batch_4
#   inflating: train_data_batch_5
# Archive:  Imagenet64_train_part2.zip
#   inflating: train_data_batch_6
#   inflating: train_data_batch_7
#   inflating: train_data_batch_8
#   inflating: train_data_batch_9
#   inflating: train_data_batch_10
# Archive:  Imagenet64_val.zip
#   inflating: val_data

# %%
# %cd ../processed
# Out:
# /content/DenseFlow/data/imagenet64/processed

# %%
mkdir -p ./{train_64x64,valid_64x64}

# %%
# !python make_imagenet_data.py --img_size 64
# Out:
# tcmalloc: large alloc 1574297600 bytes == 0x5587ae600000 @  0x7f1d4ebc41e7 0x5587ab9d5f98 0x5587ab9a0e27 0x5587aba829be 0x5587abab9802 0x5587ab9a53ce 0x5587ab9a52f9 0x5587aba5dcdd 0x5587abaeb319 0x5587aba5b94e 0x5587ab946ae0 0x5587ab9a446c 0x5587ab9a4240 0x5587aba180f3 0x5587ab9a5afa 0x5587aba13915 0x5587aba129ee 0x5587aba126f3 0x5587abadc4c2 0x5587abadc83d 0x5587abadc6e6 0x5587abab4163 0x5587abab3e0c 0x7f1d4d9aebf7 0x5587abab3cea
# tcmalloc: large alloc 1574297600 bytes == 0x55880c35e000 @  0x7f1d4ebc41e7 0x5587ab9d5f98 0x5587ab9a0e27 0x5587abaeb2c2 0x5587aba5b94e 0x5587ab946ae0 0x5587ab9a446c 0x5587ab9a4240 0x5587aba180f3 0x5587ab9a5afa 0x5587aba13915 0x5587aba129ee 0x5587aba126f3 0x5587abadc4c2 0x5587abadc83d 0x5587abadc6e6 0x5587abab4163 0x5587abab3e0c 0x7f1d4d9aebf7 0x5587abab3cea
# ...

# %%
# !python /content/DenseFlow/experiments/image/eval_loglik.py --model /content/drive/MyDrive/CMU/11785_Project/img32 --k 200 --kbs 50
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loaded weights for model at 22/22 epochs
# BATCH: 0
# BPD 3.4534530639648438
# BATCH: 1
# BPD 3.544764280319214
# BATCH: 2
# BPD 3.5536457697550454
# BATCH: 3
# BPD 3.6045032739639282
# BATCH: 4
# BPD 3.5973706245422363
# BATCH: 5
# BPD 3.602513591448466
# BATCH: 6
# BPD 3.622419459479196
# BATCH: 7
# BPD 3.626997172832489
# BATCH: 8
# BPD 3.628871864742703
# BATCH: 9
# BPD 3.647726321220398
# BATCH: 10
# BPD 3.65235634283586
# BATCH: 11
# BPD 3.6510895093282065
# BATCH: 12
# BPD 3.6437197831960826
# BATCH: 13
# ...

# %%
# !python /content/DenseFlow/experiments/image/eval_sample.py --model /content/drive/MyDrive/CMU/11785_Project/img64
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loaded weights for model at 11/11 epochs

# %%
# !python /content/DenseFlow/experiments/image/train.py --epochs 20 --batch_size 64 --optimizer adamax --lr 1e-3  --gamma 0.95 --warmup 5000  --eval_every 1 --check_every 10 --dataset imagenet32 --augmentation eta --block_conf 6 4 1 --layers_conf  5 6 20  --layer_mid_chnls 48 48 48 --growth_rate 10  --name DF_74_10
